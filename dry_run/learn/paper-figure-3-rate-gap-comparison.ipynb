# %%
import pandas as pd
import matplotlib.pyplot as plt
from plotting import aggregate_plot_x_axis_population_weighted_poverty_measure
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 from plotting import aggregate_plot_x_axis_population_weighted_poverty_measure
#
# ImportError: cannot import name 'aggregate_plot_x_axis_population_weighted_poverty_measure' from 'plotting' (/zfs/gsb/intermediate-yens/rsahoo/poverty/dry_run/learn/plotting.py)

# %%
countries = ["malawi", "ethiopia", "nigeria", "togo", "uganda"]
methods = ["binary_gap", "continuous_gap", "binary_rate", "continuous_rate", "oracle_gap"]
aggregate_plot_x_axis_population_weighted_poverty_measure(countries, methods, geo_extrapolation=True, save_as="paper-figure-3_rate_gap_comparison")
