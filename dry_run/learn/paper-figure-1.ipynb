# %%
from plotting import make_plot_for_country

# %%
make_plot_for_country('malawi', 
                      method_list=["ubi", "binary_gap", "continuous_gap", "oracle_gap"], 
                      geo_extrapolation=True, save_as='paper-figure-1a_malawi_case_study')

# %%
make_plot_for_country('malawi', 
                      method_list=["binary_gap", "continuous_gap", "binary_rate", "continuous_rate", "oracle_gap"], 
                      geo_extrapolation=True, save_as='paper-figure-1b_malawi_case_study')

# %%
for country in ["malawi", "ethiopia", "uganda", "nigeria", "togo"]:
    make_plot_for_country(country, 
                        method_list=["ubi", "pmt", "binary_gap", "continuous_gap", "binary_rate", "continuous_rate", "oracle_gap"], 
                        geo_extrapolation=True, save_as='app-figure-{}'.format(country))
