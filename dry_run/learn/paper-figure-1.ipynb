# %%
from plotting import make_plot_for_country

# %%
make_plot_for_country('malawi', method_list=["ubi", "pmt", "binary_gap", "continuous_gap", "binary_rate", "continuous_rate", "oracle_gap"], geo_extrapolation=False, save_as='paper-figure-1_malawi_case_study.pdf')
