# %%
import pandas as pd
import matplotlib.pyplot as plt
from plotting import  aggregate_plot_x_axis_fraction

# %%
countries = ["malawi", "togo", "uganda", "nigeria", "ethiopia"]
method_list = ["pmt", "ubi", "continuous_gap", "oracle_gap"]
geo_extrapolation = True

aggregate_plot_x_axis_fraction(countries, method_list=method_list, geo_extrapolation=geo_extrapolation, save_as="figure-5_percent_initial")
# Out:
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.00000000000001
# 0.0 100.0 0.0 99.99999999999999
# (0.0, 100.0) (0.0, 100.0)
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# (0.0, 100.0) (0.0, 100.0)
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 99.99999999999999
# (0.0, 100.0) (0.0, 100.0)
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# 0.0 100.0 0.0 100.0
# (0.0, 100.0) (0.0, 100.0)
# /home/users/rsahoo/zfs/gsb/intermediate-yens/rsahoo/poverty/dryrun/lib/python3.8/site-packages/scipy/interpolate/_interpolate.py:698: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# ...
