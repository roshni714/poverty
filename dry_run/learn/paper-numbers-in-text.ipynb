# %%
import pandas as pd
import numpy as np
from aggregation import get_aggregate_interpolators_population_weighted_poverty_measure_global_gap, get_aggregate_ubi_cost

# %%
amts = [] # nominal 2025 USD amts
countries = ['malawi', 'uganda', 'togo', 'nigeria', 'ethiopia']

for method in ['continuous_gap', 'oracle_gap']:
    dic = get_aggregate_interpolators_population_weighted_poverty_measure_global_gap(countries, method, geo_extrapolation=True)
    print(method, dic['gap']['interpolator'](1.))
print("ubi @ $2.15", get_aggregate_ubi_cost(countries))
# Out:
# continuous_gap 35.235180893647026
# oracle_gap 10.835333813283437
# ubi @ $2.15 135.53410876555108
