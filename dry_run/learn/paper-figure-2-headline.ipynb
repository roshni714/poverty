# %%
import pandas as pd
import matplotlib.pyplot as plt
from plotting import aggregate_plot_x_axis_population_weighted_poverty_measure_global_gap

# %%
countries = ["malawi", "ethiopia", "uganda", "nigeria", "togo"]
method_list = ["ubi", "binary_gap", "continuous_gap", "oracle_gap"]
aggregate_plot_x_axis_population_weighted_poverty_measure_global_gap(countries, method_list, geo_extrapolation=True, save_as = "paper-figure-2_headline")
