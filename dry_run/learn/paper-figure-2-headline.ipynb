# %%
import pandas as pd
import matplotlib.pyplot as plt
from plotting import aggregate_plot_x_axis_wc_poverty_measure, aggregate_plot_x_axis_population_weighted_poverty_measure

# %%
method_list = ["pmt", "ubi", "continuous_gap", "oracle_gap"]
geo_extrapolation = False


aggregate_plot_x_axis_wc_poverty_measure(["malawi", "ethiopia", "nigeria", "togo", "uganda"], method_list, geo_extrapolation)
# Out:
# max gap 5.417152716817471
# max rate 63.90466847115022
# (0, 5.417152716817471) (0, 63.90466847115022)
# max gap 5.417152716817471
# max rate 63.90466847115022
# (0, 5.417152716817471) (0, 63.90466847115022)
# max gap 5.417152716817471
# max rate 63.90466847115022
# (0, 5.417152716817471) (0, 63.90466847115022)
# max gap 5.417152716817471
# max rate 63.90466847115022
# (0, 5.417152716817471) (0, 63.90466847115022)
# /home/users/rsahoo/zfs/gsb/intermediate-yens/rsahoo/poverty/dryrun/lib/python3.8/site-packages/scipy/interpolate/_interpolate.py:698: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /home/users/rsahoo/zfs/gsb/intermediate-yens/rsahoo/poverty/dryrun/lib/python3.8/site-packages/scipy/interpolate/_interpolate.py:701: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# ...

# %%
aggregate_plot_x_axis_population_weighted_poverty_measure(["malawi", "ethiopia", "nigeria", "togo", "uganda"], method_list, geo_extrapolation)
# Out:
# initial gap 13.158839875465416
# initial rate 28.649030710401348
# max gap 5.417152716817471
# max rate 63.90466847115022
# x range gap 0.0 13.158839875465416
# (0.0, 13.158839875465416) (0.0, 28.649030710401348)
# initial gap 13.158839875465416
# initial rate 28.649030710401348
# max gap 5.417152716817471
# max rate 63.90466847115022
# x range gap 0.0 13.158839875465416
# (0.0, 13.158839875465416) (0.0, 28.649030710401348)
# initial gap 13.158839875465416
# initial rate 28.649030710401348
# max gap 5.417152716817471
# max rate 63.90466847115022
# x range gap 0.0 13.158839875465416
# (0.0, 13.158839875465416) (0.0, 28.649030710401348)
# initial gap 13.158839875465416
# initial rate 28.649030710401348
# max gap 5.417152716817471
# max rate 63.90466847115022
# x range gap 0.0 13.158839875465416
# (0.0, 13.158839875465416) (0.0, 28.649030710401348)
# ...
